# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyDMmendes/beecrowd_c99/blob/main/10_dicionarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXEMPLO 01
almoco = {'comida': 'Lanche', 'bebida': 'Água', 'sobremesa': 'Pudim'}
print(almoco)
print(type(almoco))

# EXEMPLO 02
almoco = {
    'comida': 'Lanche',
    'bebida': 'Água',
    'sobremesa': 'Pudim'
    }

print(almoco.items())

# EXEMPLO 03
print(almoco.keys())

# EXEMPLO 04
print(almoco.values())

# EXEMPLO 05
print(almoco['sobremesa'])

# EXEMPLO 06
for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>12}")

# EXEMPLO 07 (Alterar valores no dicionário)
almoco['bebida'] = 'Suco de laranja'

for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>18}")

# EXEMPLO 08 (Remover itens do dicionário)
del almoco['sobremesa']

for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>18}")

# EXEMPLO 09
estado = {}
brasil = []

for e in range(2):
    estado['uf'] = input("Digite a UF: ")
    estado['sigla'] = input("Digite a sigla: ")
    brasil.append(estado.copy())

print(brasil)

# EXEMPLO 10
for e in brasil:
    for valor in e.values():
        print(valor)
